# %%
import cv2
import mediapipe as mp
import numpy as np
import csv
import os
import time

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=False, max_num_hands=1, min_detection_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

# Create directories for storing the data
os.makedirs('data', exist_ok=True)

# Define function to extract hand landmarks
def extract_hand_landmarks(image):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = hands.process(image_rgb)
    
    if results.multi_hand_landmarks:
        landmarks = results.multi_hand_landmarks[0]
        landmarks_array = np.array(
            [(lm.x, lm.y, lm.z) for lm in landmarks.landmark]).flatten()
        return landmarks_array, results
    return None, None

# Capture images and save landmarks
def capture_hand_signs(sign_name, num_samples=500):
    cap = cv2.VideoCapture(0)
    collected_samples = 0

    # Create a CSV file to store the landmarks
    with open(f'data/{sign_name}.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([f'landmark_{i}' for i in range(63)] + ['label'])
        
        while cap.isOpened() and collected_samples < num_samples:
            success, image = cap.read()
            if not success:
                break

            landmarks, results = extract_hand_landmarks(image)
            if landmarks is not None:
                writer.writerow(np.append(landmarks, sign_name))
                collected_samples += 1
                print(f"Collected {collected_samples}/{num_samples} samples for {sign_name}")
                # Draw hand landmarks on the image
                mp_drawing.draw_landmarks(image, results.multi_hand_landmarks[0], mp_hands.HAND_CONNECTIONS)
                # Wait for 2 seconds before capturing the next sample
                time.sleep(1)

            cv2.imshow('Capture Hand Signs', image)
            if cv2.waitKey(5) & 0xFF == 27:  # Press 'Esc' to exit
                break

    cap.release()
    cv2.destroyAllWindows()

# Capture hand signs for 'sign1' and 'sign2'
capture_hand_signs('Normal', num_samples=500)
capture_hand_signs('help_1', num_samples=500)
capture_hand_signs('help_2', num_samples=500)
# Out:
# Collected 1/500 samples for Normal
# Collected 2/500 samples for Normal
# Collected 3/500 samples for Normal
# Collected 4/500 samples for Normal
# Collected 5/500 samples for Normal
# Collected 6/500 samples for Normal
# Collected 7/500 samples for Normal
# Collected 8/500 samples for Normal
# Collected 9/500 samples for Normal
# Collected 10/500 samples for Normal
# Collected 11/500 samples for Normal
# Collected 12/500 samples for Normal
# Collected 13/500 samples for Normal
# Collected 14/500 samples for Normal
# Collected 15/500 samples for Normal
# Collected 16/500 samples for Normal
# Collected 17/500 samples for Normal
# Collected 18/500 samples for Normal
# Collected 19/500 samples for Normal
# Collected 20/500 samples for Normal
# Collected 21/500 samples for Normal
# Collected 22/500 samples for Normal
# Collected 23/500 samples for Normal
# Collected 24/500 samples for Normal
# Collected 25/500 samples for Normal
# Collected 26/500 samples for Normal
# Collected 27/500 samples for Normal
# Collected 28/500 samples for Normal
# Collected 29/500 samples for Normal
# Collected 30/500 samples for Normal
# Collected 31/500 samples for Normal
# Collected 32/500 samples for Normal
# Collected 33/500 samples for Normal
# Collected 34/500 samples for Normal
# Collected 35/500 samples for Normal
# Collected 36/500 samples for Normal
# Collected 37/500 samples for Normal
# Collected 38/500 samples for Normal
# Collected 39/500 samples for Normal
# Collected 40/500 samples for Normal
# Collected 41/500 samples for Normal
# Collected 42/500 samples for Normal
# Collected 43/500 samples for Normal
# Collected 44/500 samples for Normal
# Collected 45/500 samples for Normal
# Collected 46/500 samples for Normal
# Collected 47/500 samples for Normal
# Collected 48/500 samples for Normal
# Collected 49/500 samples for Normal
# Collected 50/500 samples for Normal
# Collected 51/500 samples for Normal
# Collected 52/500 samples for Normal
# Collected 53/500 samples for Normal
# Collected 54/500 samples for Normal
# Collected 55/500 samples for Normal
# Collected 56/500 samples for Normal
# Collected 57/500 samples for Normal
# Collected 58/500 samples for Normal
# Collected 59/500 samples for Normal
# Collected 60/500 samples for Normal
# Collected 61/500 samples for Normal
# Collected 62/500 samples for Normal
# Collected 63/500 samples for Normal
# Collected 64/500 samples for Normal
# Collected 65/500 samples for Normal
# Collected 66/500 samples for Normal
# Collected 67/500 samples for Normal
# Collected 68/500 samples for Normal
# Collected 69/500 samples for Normal
# Collected 70/500 samples for Normal
# Collected 71/500 samples for Normal
# Collected 72/500 samples for Normal
# Collected 73/500 samples for Normal
# Collected 74/500 samples for Normal
# Collected 75/500 samples for Normal
# Collected 76/500 samples for Normal
# Collected 77/500 samples for Normal
# Collected 78/500 samples for Normal
# Collected 79/500 samples for Normal
# Collected 80/500 samples for Normal
# Collected 81/500 samples for Normal
# Collected 82/500 samples for Normal
# Collected 83/500 samples for Normal
# Collected 84/500 samples for Normal
# Collected 85/500 samples for Normal
# Collected 86/500 samples for Normal
# Collected 87/500 samples for Normal
# Collected 88/500 samples for Normal
# Collected 89/500 samples for Normal
# Collected 90/500 samples for Normal
# Collected 91/500 samples for Normal
# Collected 92/500 samples for Normal
# Collected 93/500 samples for Normal
# Collected 94/500 samples for Normal
# Collected 95/500 samples for Normal
# Collected 96/500 samples for Normal
# Collected 97/500 samples for Normal
# Collected 98/500 samples for Normal
# Collected 99/500 samples for Normal
# Collected 100/500 samples for Normal
# Collected 101/500 samples for Normal
# Collected 102/500 samples for Normal
# Collected 103/500 samples for Normal
# Collected 104/500 samples for Normal
# Collected 105/500 samples for Normal
# Collected 106/500 samples for Normal
# Collected 107/500 samples for Normal
# Collected 108/500 samples for Normal
# Collected 109/500 samples for Normal
# Collected 110/500 samples for Normal
# Collected 111/500 samples for Normal
# Collected 112/500 samples for Normal
# Collected 113/500 samples for Normal
# Collected 114/500 samples for Normal
# Collected 115/500 samples for Normal
# Collected 116/500 samples for Normal
# Collected 117/500 samples for Normal
# Collected 118/500 samples for Normal
# Collected 119/500 samples for Normal
# Collected 120/500 samples for Normal
# Collected 121/500 samples for Normal
# Collected 122/500 samples for Normal
# Collected 123/500 samples for Normal
# Collected 124/500 samples for Normal
# Collected 125/500 samples for Normal
# Collected 126/500 samples for Normal
# Collected 127/500 samples for Normal
# Collected 128/500 samples for Normal
# Collected 129/500 samples for Normal
# Collected 130/500 samples for Normal
# Collected 131/500 samples for Normal
# Collected 132/500 samples for Normal
# Collected 133/500 samples for Normal
# Collected 134/500 samples for Normal
# Collected 135/500 samples for Normal
# Collected 136/500 samples for Normal
# Collected 137/500 samples for Normal
# Collected 138/500 samples for Normal
# Collected 139/500 samples for Normal
# Collected 140/500 samples for Normal
# Collected 141/500 samples for Normal
# Collected 142/500 samples for Normal
# Collected 143/500 samples for Normal
# Collected 144/500 samples for Normal
# Collected 145/500 samples for Normal
# Collected 146/500 samples for Normal
# Collected 147/500 samples for Normal
# Collected 148/500 samples for Normal
# Collected 149/500 samples for Normal
# Collected 150/500 samples for Normal
# Collected 151/500 samples for Normal
# Collected 152/500 samples for Normal
# Collected 153/500 samples for Normal
# Collected 154/500 samples for Normal
# Collected 155/500 samples for Normal
# Collected 156/500 samples for Normal
# Collected 157/500 samples for Normal
# Collected 158/500 samples for Normal
# Collected 159/500 samples for Normal
# Collected 160/500 samples for Normal
# Collected 161/500 samples for Normal
# Collected 162/500 samples for Normal
# Collected 163/500 samples for Normal
# Collected 164/500 samples for Normal
# Collected 165/500 samples for Normal
# Collected 166/500 samples for Normal
# Collected 167/500 samples for Normal
# Collected 168/500 samples for Normal
# Collected 169/500 samples for Normal
# Collected 170/500 samples for Normal
# Collected 171/500 samples for Normal
# Collected 172/500 samples for Normal
# Collected 173/500 samples for Normal
# Collected 174/500 samples for Normal
# Collected 175/500 samples for Normal
# Collected 176/500 samples for Normal
# Collected 177/500 samples for Normal
# Collected 178/500 samples for Normal
# Collected 179/500 samples for Normal
# Collected 180/500 samples for Normal
# Collected 181/500 samples for Normal
# Collected 182/500 samples for Normal
# Collected 183/500 samples for Normal
# Collected 184/500 samples for Normal
# Collected 185/500 samples for Normal
# Collected 186/500 samples for Normal
# Collected 187/500 samples for Normal
# Collected 188/500 samples for Normal
# Collected 189/500 samples for Normal
# Collected 190/500 samples for Normal
# Collected 191/500 samples for Normal
# Collected 192/500 samples for Normal
# Collected 193/500 samples for Normal
# Collected 194/500 samples for Normal
# Collected 195/500 samples for Normal
# Collected 196/500 samples for Normal
# Collected 197/500 samples for Normal
# Collected 198/500 samples for Normal
# Collected 199/500 samples for Normal
# Collected 200/500 samples for Normal
# Collected 201/500 samples for Normal
# Collected 202/500 samples for Normal
# Collected 203/500 samples for Normal
# Collected 204/500 samples for Normal
# Collected 205/500 samples for Normal
# Collected 206/500 samples for Normal
# Collected 207/500 samples for Normal
# Collected 208/500 samples for Normal
# Collected 209/500 samples for Normal
# Collected 210/500 samples for Normal
# Collected 211/500 samples for Normal
# Collected 212/500 samples for Normal
# Collected 213/500 samples for Normal
# Collected 214/500 samples for Normal
# Collected 215/500 samples for Normal
# Collected 216/500 samples for Normal
# Collected 217/500 samples for Normal
# Collected 218/500 samples for Normal
# Collected 219/500 samples for Normal
# Collected 220/500 samples for Normal
# Collected 221/500 samples for Normal
# Collected 222/500 samples for Normal
# Collected 223/500 samples for Normal
# Collected 224/500 samples for Normal
# Collected 225/500 samples for Normal
# Collected 226/500 samples for Normal
# Collected 227/500 samples for Normal
# Collected 228/500 samples for Normal
# Collected 229/500 samples for Normal
# Collected 230/500 samples for Normal
# Collected 231/500 samples for Normal
# Collected 232/500 samples for Normal
# Collected 233/500 samples for Normal
# Collected 234/500 samples for Normal
# Collected 235/500 samples for Normal
# Collected 236/500 samples for Normal
# Collected 237/500 samples for Normal
# Collected 238/500 samples for Normal
# Collected 239/500 samples for Normal
# Collected 240/500 samples for Normal
# Collected 241/500 samples for Normal
# Collected 242/500 samples for Normal
# Collected 243/500 samples for Normal
# Collected 244/500 samples for Normal
# Collected 245/500 samples for Normal
# Collected 246/500 samples for Normal
# Collected 247/500 samples for Normal
# Collected 248/500 samples for Normal
# Collected 249/500 samples for Normal
# Collected 250/500 samples for Normal
# Collected 251/500 samples for Normal
# Collected 252/500 samples for Normal
# Collected 253/500 samples for Normal
# Collected 254/500 samples for Normal
# Collected 255/500 samples for Normal
# Collected 256/500 samples for Normal
# Collected 257/500 samples for Normal
# Collected 258/500 samples for Normal
# Collected 259/500 samples for Normal
# Collected 260/500 samples for Normal
# Collected 261/500 samples for Normal
# Collected 262/500 samples for Normal
# Collected 263/500 samples for Normal
# Collected 264/500 samples for Normal
# Collected 265/500 samples for Normal
# Collected 266/500 samples for Normal
# Collected 267/500 samples for Normal
# Collected 268/500 samples for Normal
# Collected 269/500 samples for Normal
# Collected 270/500 samples for Normal
# Collected 271/500 samples for Normal
# Collected 272/500 samples for Normal
# Collected 273/500 samples for Normal
# Collected 274/500 samples for Normal
# Collected 275/500 samples for Normal
# Collected 276/500 samples for Normal
# Collected 277/500 samples for Normal
# Collected 278/500 samples for Normal
# Collected 279/500 samples for Normal
# Collected 280/500 samples for Normal
# Collected 281/500 samples for Normal
# Collected 282/500 samples for Normal
# Collected 283/500 samples for Normal
# Collected 284/500 samples for Normal
# Collected 285/500 samples for Normal
# Collected 286/500 samples for Normal
# Collected 287/500 samples for Normal
# Collected 288/500 samples for Normal
# Collected 289/500 samples for Normal
# Collected 290/500 samples for Normal
# Collected 291/500 samples for Normal
# Collected 292/500 samples for Normal
# Collected 293/500 samples for Normal
# Collected 294/500 samples for Normal
# Collected 295/500 samples for Normal
# Collected 296/500 samples for Normal
# Collected 297/500 samples for Normal
# Collected 298/500 samples for Normal
# Collected 299/500 samples for Normal
# Collected 300/500 samples for Normal
# Collected 301/500 samples for Normal
# Collected 302/500 samples for Normal
# Collected 303/500 samples for Normal
# Collected 304/500 samples for Normal
# Collected 305/500 samples for Normal
# Collected 306/500 samples for Normal
# Collected 307/500 samples for Normal
# Collected 308/500 samples for Normal
# Collected 309/500 samples for Normal
# Collected 310/500 samples for Normal
# Collected 311/500 samples for Normal
# Collected 312/500 samples for Normal
# Collected 313/500 samples for Normal
# Collected 314/500 samples for Normal
# Collected 315/500 samples for Normal
# Collected 316/500 samples for Normal
# Collected 317/500 samples for Normal
# Collected 318/500 samples for Normal
# Collected 319/500 samples for Normal
# Collected 320/500 samples for Normal
# Collected 321/500 samples for Normal
# Collected 322/500 samples for Normal
# Collected 323/500 samples for Normal
# Collected 324/500 samples for Normal
# Collected 325/500 samples for Normal
# Collected 326/500 samples for Normal
# Collected 327/500 samples for Normal
# Collected 328/500 samples for Normal
# Collected 329/500 samples for Normal
# Collected 330/500 samples for Normal
# Collected 331/500 samples for Normal
# Collected 332/500 samples for Normal
# Collected 333/500 samples for Normal
# Collected 334/500 samples for Normal
# Collected 335/500 samples for Normal
# Collected 336/500 samples for Normal
# Collected 337/500 samples for Normal
# Collected 338/500 samples for Normal
# Collected 339/500 samples for Normal
# Collected 340/500 samples for Normal
# Collected 341/500 samples for Normal
# Collected 342/500 samples for Normal
# Collected 343/500 samples for Normal
# Collected 344/500 samples for Normal
# Collected 345/500 samples for Normal
# Collected 346/500 samples for Normal
# Collected 347/500 samples for Normal
# Collected 348/500 samples for Normal
# Collected 349/500 samples for Normal
# Collected 350/500 samples for Normal
# Collected 351/500 samples for Normal
# Collected 352/500 samples for Normal
# Collected 353/500 samples for Normal
# Collected 354/500 samples for Normal
# Collected 355/500 samples for Normal
# Collected 356/500 samples for Normal
# Collected 357/500 samples for Normal
# Collected 358/500 samples for Normal
# Collected 359/500 samples for Normal
# Collected 360/500 samples for Normal
# Collected 361/500 samples for Normal
# Collected 362/500 samples for Normal
# Collected 363/500 samples for Normal
# Collected 364/500 samples for Normal
# Collected 365/500 samples for Normal
# Collected 366/500 samples for Normal
# Collected 367/500 samples for Normal
# Collected 368/500 samples for Normal
# Collected 369/500 samples for Normal
# Collected 370/500 samples for Normal
# Collected 371/500 samples for Normal
# Collected 372/500 samples for Normal
# Collected 373/500 samples for Normal
# Collected 374/500 samples for Normal
# Collected 375/500 samples for Normal
# Collected 376/500 samples for Normal
# Collected 377/500 samples for Normal
# Collected 378/500 samples for Normal
# Collected 379/500 samples for Normal
# Collected 380/500 samples for Normal
# Collected 381/500 samples for Normal
# Collected 382/500 samples for Normal
# Collected 383/500 samples for Normal
# Collected 384/500 samples for Normal
# Collected 385/500 samples for Normal
# Collected 386/500 samples for Normal
# Collected 387/500 samples for Normal
# Collected 388/500 samples for Normal
# Collected 389/500 samples for Normal
# Collected 390/500 samples for Normal
# Collected 391/500 samples for Normal
# Collected 392/500 samples for Normal
# Collected 393/500 samples for Normal
# Collected 394/500 samples for Normal
# Collected 395/500 samples for Normal
# Collected 396/500 samples for Normal
# Collected 397/500 samples for Normal
# Collected 398/500 samples for Normal
# Collected 399/500 samples for Normal
# Collected 400/500 samples for Normal
# Collected 401/500 samples for Normal
# Collected 402/500 samples for Normal
# Collected 403/500 samples for Normal
# Collected 404/500 samples for Normal
# Collected 405/500 samples for Normal
# Collected 406/500 samples for Normal
# Collected 407/500 samples for Normal
# Collected 408/500 samples for Normal
# Collected 409/500 samples for Normal
# Collected 410/500 samples for Normal
# Collected 411/500 samples for Normal
# Collected 412/500 samples for Normal
# Collected 413/500 samples for Normal
# Collected 414/500 samples for Normal
# Collected 415/500 samples for Normal
# Collected 416/500 samples for Normal
# Collected 417/500 samples for Normal
# Collected 418/500 samples for Normal
# Collected 419/500 samples for Normal
# Collected 420/500 samples for Normal
# Collected 421/500 samples for Normal
# Collected 422/500 samples for Normal
# Collected 423/500 samples for Normal
# Collected 424/500 samples for Normal
# Collected 425/500 samples for Normal
# Collected 426/500 samples for Normal
# Collected 427/500 samples for Normal
# Collected 428/500 samples for Normal
# Collected 429/500 samples for Normal
# Collected 430/500 samples for Normal
# Collected 431/500 samples for Normal
# Collected 432/500 samples for Normal
# Collected 433/500 samples for Normal
# Collected 434/500 samples for Normal
# Collected 435/500 samples for Normal
# Collected 436/500 samples for Normal
# Collected 437/500 samples for Normal
# Collected 438/500 samples for Normal
# Collected 439/500 samples for Normal
# Collected 440/500 samples for Normal
# Collected 441/500 samples for Normal
# Collected 442/500 samples for Normal
# Collected 443/500 samples for Normal
# Collected 444/500 samples for Normal
# Collected 445/500 samples for Normal
# Collected 446/500 samples for Normal
# Collected 447/500 samples for Normal
# Collected 448/500 samples for Normal
# Collected 449/500 samples for Normal
# Collected 450/500 samples for Normal
# Collected 451/500 samples for Normal
# Collected 452/500 samples for Normal
# Collected 453/500 samples for Normal
# Collected 454/500 samples for Normal
# Collected 455/500 samples for Normal
# Collected 456/500 samples for Normal
# Collected 457/500 samples for Normal
# Collected 458/500 samples for Normal
# Collected 459/500 samples for Normal
# Collected 460/500 samples for Normal
# Collected 461/500 samples for Normal
# Collected 462/500 samples for Normal
# Collected 463/500 samples for Normal
# Collected 464/500 samples for Normal
# Collected 465/500 samples for Normal
# Collected 466/500 samples for Normal
# Collected 467/500 samples for Normal
# Collected 468/500 samples for Normal
# Collected 469/500 samples for Normal
# Collected 470/500 samples for Normal
# Collected 471/500 samples for Normal
# Collected 472/500 samples for Normal
# Collected 473/500 samples for Normal
# Collected 474/500 samples for Normal
# Collected 475/500 samples for Normal
# Collected 476/500 samples for Normal
# Collected 477/500 samples for Normal
# Collected 478/500 samples for Normal
# Collected 479/500 samples for Normal
# Collected 480/500 samples for Normal
# Collected 481/500 samples for Normal
# Collected 482/500 samples for Normal
# Collected 483/500 samples for Normal
# Collected 484/500 samples for Normal
# Collected 485/500 samples for Normal
# Collected 486/500 samples for Normal
# Collected 487/500 samples for Normal
# Collected 488/500 samples for Normal
# Collected 489/500 samples for Normal
# Collected 490/500 samples for Normal
# Collected 491/500 samples for Normal
# Collected 492/500 samples for Normal
# Collected 493/500 samples for Normal
# Collected 494/500 samples for Normal
# Collected 495/500 samples for Normal
# Collected 496/500 samples for Normal
# Collected 497/500 samples for Normal
# Collected 498/500 samples for Normal
# Collected 499/500 samples for Normal
# Collected 500/500 samples for Normal
# Collected 1/500 samples for help_1
# Collected 2/500 samples for help_1
# Collected 3/500 samples for help_1
# Collected 4/500 samples for help_1
# Collected 5/500 samples for help_1
# Collected 6/500 samples for help_1
# Collected 7/500 samples for help_1
# Collected 8/500 samples for help_1
# Collected 9/500 samples for help_1
# Collected 10/500 samples for help_1
# Collected 11/500 samples for help_1
# Collected 12/500 samples for help_1
# Collected 13/500 samples for help_1
# Collected 14/500 samples for help_1
# Collected 15/500 samples for help_1
# Collected 16/500 samples for help_1
# Collected 17/500 samples for help_1
# Collected 18/500 samples for help_1
# Collected 19/500 samples for help_1
# Collected 20/500 samples for help_1
# Collected 21/500 samples for help_1
# Collected 22/500 samples for help_1
# Collected 23/500 samples for help_1
# Collected 24/500 samples for help_1
# Collected 25/500 samples for help_1
# Collected 26/500 samples for help_1
# Collected 27/500 samples for help_1
# Collected 28/500 samples for help_1
# Collected 29/500 samples for help_1
# Collected 30/500 samples for help_1
# Collected 31/500 samples for help_1
# Collected 32/500 samples for help_1
# Collected 33/500 samples for help_1
# Collected 34/500 samples for help_1
# Collected 35/500 samples for help_1
# Collected 36/500 samples for help_1
# Collected 37/500 samples for help_1
# Collected 38/500 samples for help_1
# Collected 39/500 samples for help_1
# Collected 40/500 samples for help_1
# Collected 41/500 samples for help_1
# Collected 42/500 samples for help_1
# Collected 43/500 samples for help_1
# Collected 44/500 samples for help_1
# Collected 45/500 samples for help_1
# Collected 46/500 samples for help_1
# Collected 47/500 samples for help_1
# Collected 48/500 samples for help_1
# Collected 49/500 samples for help_1
# Collected 50/500 samples for help_1
# Collected 51/500 samples for help_1
# Collected 52/500 samples for help_1
# Collected 53/500 samples for help_1
# Collected 54/500 samples for help_1
# Collected 55/500 samples for help_1
# Collected 56/500 samples for help_1
# Collected 57/500 samples for help_1
# Collected 58/500 samples for help_1
# Collected 59/500 samples for help_1
# Collected 60/500 samples for help_1
# Collected 61/500 samples for help_1
# Collected 62/500 samples for help_1
# Collected 63/500 samples for help_1
# Collected 64/500 samples for help_1
# Collected 65/500 samples for help_1
# Collected 66/500 samples for help_1
# Collected 67/500 samples for help_1
# Collected 68/500 samples for help_1
# Collected 69/500 samples for help_1
# Collected 70/500 samples for help_1
# Collected 71/500 samples for help_1
# Collected 72/500 samples for help_1
# Collected 73/500 samples for help_1
# Collected 74/500 samples for help_1
# Collected 75/500 samples for help_1
# Collected 76/500 samples for help_1
# Collected 77/500 samples for help_1
# Collected 78/500 samples for help_1
# Collected 79/500 samples for help_1
# Collected 80/500 samples for help_1
# Collected 81/500 samples for help_1
# Collected 82/500 samples for help_1
# Collected 83/500 samples for help_1
# Collected 84/500 samples for help_1
# Collected 85/500 samples for help_1
# Collected 86/500 samples for help_1
# Collected 87/500 samples for help_1
# Collected 88/500 samples for help_1
# Collected 89/500 samples for help_1
# Collected 90/500 samples for help_1
# Collected 91/500 samples for help_1
# Collected 92/500 samples for help_1
# Collected 93/500 samples for help_1
# Collected 94/500 samples for help_1
# Collected 95/500 samples for help_1
# Collected 96/500 samples for help_1
# Collected 97/500 samples for help_1
# Collected 98/500 samples for help_1
# Collected 99/500 samples for help_1
# Collected 100/500 samples for help_1
# Collected 101/500 samples for help_1
# Collected 102/500 samples for help_1
# Collected 103/500 samples for help_1
# Collected 104/500 samples for help_1
# Collected 105/500 samples for help_1
# Collected 106/500 samples for help_1
# Collected 107/500 samples for help_1
# Collected 108/500 samples for help_1
# Collected 109/500 samples for help_1
# Collected 110/500 samples for help_1
# Collected 111/500 samples for help_1
# Collected 112/500 samples for help_1
# Collected 113/500 samples for help_1
# Collected 114/500 samples for help_1
# Collected 115/500 samples for help_1
# Collected 116/500 samples for help_1
# Collected 117/500 samples for help_1
# Collected 118/500 samples for help_1
# Collected 119/500 samples for help_1
# Collected 120/500 samples for help_1
# Collected 121/500 samples for help_1
# Collected 122/500 samples for help_1
# Collected 123/500 samples for help_1
# Collected 124/500 samples for help_1
# Collected 125/500 samples for help_1
# Collected 126/500 samples for help_1
# Collected 127/500 samples for help_1
# Collected 128/500 samples for help_1
# Collected 129/500 samples for help_1
# Collected 130/500 samples for help_1
# Collected 131/500 samples for help_1
# Collected 132/500 samples for help_1
# Collected 133/500 samples for help_1
# Collected 134/500 samples for help_1
# Collected 135/500 samples for help_1
# Collected 136/500 samples for help_1
# Collected 137/500 samples for help_1
# Collected 138/500 samples for help_1
# Collected 139/500 samples for help_1
# Collected 140/500 samples for help_1
# Collected 141/500 samples for help_1
# Collected 142/500 samples for help_1
# Collected 143/500 samples for help_1
# Collected 144/500 samples for help_1
# Collected 145/500 samples for help_1
# Collected 146/500 samples for help_1
# Collected 147/500 samples for help_1
# Collected 148/500 samples for help_1
# Collected 149/500 samples for help_1
# Collected 150/500 samples for help_1
# Collected 151/500 samples for help_1
# Collected 152/500 samples for help_1
# Collected 153/500 samples for help_1
# Collected 154/500 samples for help_1
# Collected 155/500 samples for help_1
# Collected 156/500 samples for help_1
# Collected 157/500 samples for help_1
# Collected 158/500 samples for help_1
# Collected 159/500 samples for help_1
# Collected 160/500 samples for help_1
# Collected 161/500 samples for help_1
# Collected 162/500 samples for help_1
# Collected 163/500 samples for help_1
# Collected 164/500 samples for help_1
# Collected 165/500 samples for help_1
# Collected 166/500 samples for help_1
# Collected 167/500 samples for help_1
# Collected 168/500 samples for help_1
# Collected 169/500 samples for help_1
# Collected 170/500 samples for help_1
# Collected 171/500 samples for help_1
# Collected 172/500 samples for help_1
# Collected 173/500 samples for help_1
# Collected 174/500 samples for help_1
# Collected 175/500 samples for help_1
# Collected 176/500 samples for help_1
# Collected 177/500 samples for help_1
# Collected 178/500 samples for help_1
# Collected 179/500 samples for help_1
# Collected 180/500 samples for help_1
# Collected 181/500 samples for help_1
# Collected 182/500 samples for help_1
# Collected 183/500 samples for help_1
# Collected 184/500 samples for help_1
# Collected 185/500 samples for help_1
# Collected 186/500 samples for help_1
# Collected 187/500 samples for help_1
# Collected 188/500 samples for help_1
# Collected 189/500 samples for help_1
# Collected 190/500 samples for help_1
# Collected 191/500 samples for help_1
# Collected 192/500 samples for help_1
# Collected 193/500 samples for help_1
# Collected 194/500 samples for help_1
# Collected 195/500 samples for help_1
# Collected 196/500 samples for help_1
# Collected 197/500 samples for help_1
# Collected 198/500 samples for help_1
# Collected 199/500 samples for help_1
# Collected 200/500 samples for help_1
# Collected 201/500 samples for help_1
# Collected 202/500 samples for help_1
# Collected 203/500 samples for help_1
# Collected 204/500 samples for help_1
# Collected 205/500 samples for help_1
# Collected 206/500 samples for help_1
# Collected 207/500 samples for help_1
# Collected 208/500 samples for help_1
# Collected 209/500 samples for help_1
# Collected 210/500 samples for help_1
# Collected 211/500 samples for help_1
# Collected 212/500 samples for help_1
# Collected 213/500 samples for help_1
# Collected 214/500 samples for help_1
# Collected 215/500 samples for help_1
# Collected 216/500 samples for help_1
# Collected 217/500 samples for help_1
# Collected 218/500 samples for help_1
# Collected 219/500 samples for help_1
# Collected 220/500 samples for help_1
# Collected 221/500 samples for help_1
# Collected 222/500 samples for help_1
# Collected 223/500 samples for help_1
# Collected 224/500 samples for help_1
# Collected 225/500 samples for help_1
# Collected 226/500 samples for help_1
# Collected 227/500 samples for help_1
# Collected 228/500 samples for help_1
# Collected 229/500 samples for help_1
# Collected 230/500 samples for help_1
# Collected 231/500 samples for help_1
# Collected 232/500 samples for help_1
# Collected 233/500 samples for help_1
# Collected 234/500 samples for help_1
# Collected 235/500 samples for help_1
# Collected 236/500 samples for help_1
# Collected 237/500 samples for help_1
# Collected 238/500 samples for help_1
# Collected 239/500 samples for help_1
# Collected 240/500 samples for help_1
# Collected 241/500 samples for help_1
# Collected 242/500 samples for help_1
# Collected 243/500 samples for help_1
# Collected 244/500 samples for help_1
# Collected 245/500 samples for help_1
# Collected 246/500 samples for help_1
# Collected 247/500 samples for help_1
# Collected 248/500 samples for help_1
# Collected 249/500 samples for help_1
# Collected 250/500 samples for help_1
# Collected 251/500 samples for help_1
# Collected 252/500 samples for help_1
# Collected 253/500 samples for help_1
# Collected 254/500 samples for help_1
# Collected 255/500 samples for help_1
# Collected 256/500 samples for help_1
# Collected 257/500 samples for help_1
# Collected 258/500 samples for help_1
# Collected 259/500 samples for help_1
# Collected 260/500 samples for help_1
# Collected 261/500 samples for help_1
# Collected 262/500 samples for help_1
# Collected 263/500 samples for help_1
# Collected 264/500 samples for help_1
# Collected 265/500 samples for help_1
# Collected 266/500 samples for help_1
# Collected 267/500 samples for help_1
# Collected 268/500 samples for help_1
# Collected 269/500 samples for help_1
# Collected 270/500 samples for help_1
# Collected 271/500 samples for help_1
# Collected 272/500 samples for help_1
# Collected 273/500 samples for help_1
# Collected 274/500 samples for help_1
# Collected 275/500 samples for help_1
# Collected 276/500 samples for help_1
# Collected 277/500 samples for help_1
# Collected 278/500 samples for help_1
# Collected 279/500 samples for help_1
# Collected 280/500 samples for help_1
# Collected 281/500 samples for help_1
# Collected 282/500 samples for help_1
# Collected 283/500 samples for help_1
# Collected 284/500 samples for help_1
# Collected 285/500 samples for help_1
# Collected 286/500 samples for help_1
# Collected 287/500 samples for help_1
# Collected 288/500 samples for help_1
# Collected 289/500 samples for help_1
# Collected 290/500 samples for help_1
# Collected 291/500 samples for help_1
# Collected 292/500 samples for help_1
# Collected 293/500 samples for help_1
# Collected 294/500 samples for help_1
# Collected 295/500 samples for help_1
# Collected 296/500 samples for help_1
# Collected 297/500 samples for help_1
# Collected 298/500 samples for help_1
# Collected 299/500 samples for help_1
# Collected 300/500 samples for help_1
# Collected 301/500 samples for help_1
# Collected 302/500 samples for help_1
# Collected 303/500 samples for help_1
# Collected 304/500 samples for help_1
# Collected 305/500 samples for help_1
# Collected 306/500 samples for help_1
# Collected 307/500 samples for help_1
# Collected 308/500 samples for help_1
# Collected 309/500 samples for help_1
# Collected 310/500 samples for help_1
# Collected 311/500 samples for help_1
# Collected 312/500 samples for help_1
# Collected 313/500 samples for help_1
# Collected 314/500 samples for help_1
# Collected 315/500 samples for help_1
# Collected 316/500 samples for help_1
# Collected 317/500 samples for help_1
# Collected 318/500 samples for help_1
# Collected 319/500 samples for help_1
# Collected 320/500 samples for help_1
# Collected 321/500 samples for help_1
# Collected 322/500 samples for help_1
# Collected 323/500 samples for help_1
# Collected 324/500 samples for help_1
# Collected 325/500 samples for help_1
# Collected 326/500 samples for help_1
# Collected 327/500 samples for help_1
# Collected 328/500 samples for help_1
# Collected 329/500 samples for help_1
# Collected 330/500 samples for help_1
# Collected 331/500 samples for help_1
# Collected 332/500 samples for help_1
# Collected 333/500 samples for help_1
# Collected 334/500 samples for help_1
# Collected 335/500 samples for help_1
# Collected 336/500 samples for help_1
# Collected 337/500 samples for help_1
# Collected 338/500 samples for help_1
# Collected 339/500 samples for help_1
# Collected 340/500 samples for help_1
# Collected 341/500 samples for help_1
# Collected 342/500 samples for help_1
# Collected 343/500 samples for help_1
# Collected 344/500 samples for help_1
# Collected 345/500 samples for help_1
# Collected 346/500 samples for help_1
# Collected 347/500 samples for help_1
# Collected 348/500 samples for help_1
# Collected 349/500 samples for help_1
# Collected 350/500 samples for help_1
# Collected 351/500 samples for help_1
# Collected 352/500 samples for help_1
# Collected 353/500 samples for help_1
# Collected 354/500 samples for help_1
# Collected 355/500 samples for help_1
# Collected 356/500 samples for help_1
# Collected 357/500 samples for help_1
# Collected 358/500 samples for help_1
# Collected 359/500 samples for help_1
# Collected 360/500 samples for help_1
# Collected 361/500 samples for help_1
# Collected 362/500 samples for help_1
# Collected 363/500 samples for help_1
# Collected 364/500 samples for help_1
# Collected 365/500 samples for help_1
# Collected 366/500 samples for help_1
# Collected 367/500 samples for help_1
# Collected 368/500 samples for help_1
# Collected 369/500 samples for help_1
# Collected 370/500 samples for help_1
# Collected 371/500 samples for help_1
# Collected 372/500 samples for help_1
# Collected 373/500 samples for help_1
# Collected 374/500 samples for help_1
# Collected 375/500 samples for help_1
# Collected 376/500 samples for help_1
# Collected 377/500 samples for help_1
# Collected 378/500 samples for help_1
# Collected 379/500 samples for help_1
# Collected 380/500 samples for help_1
# Collected 381/500 samples for help_1
# Collected 382/500 samples for help_1
# Collected 383/500 samples for help_1
# Collected 384/500 samples for help_1
# Collected 385/500 samples for help_1
# Collected 386/500 samples for help_1
# Collected 387/500 samples for help_1
# Collected 388/500 samples for help_1
# Collected 389/500 samples for help_1
# Collected 390/500 samples for help_1
# Collected 391/500 samples for help_1
# Collected 392/500 samples for help_1
# Collected 393/500 samples for help_1
# Collected 394/500 samples for help_1
# Collected 395/500 samples for help_1
# Collected 396/500 samples for help_1
# Collected 397/500 samples for help_1
# Collected 398/500 samples for help_1
# Collected 399/500 samples for help_1
# Collected 400/500 samples for help_1
# Collected 401/500 samples for help_1
# Collected 402/500 samples for help_1
# Collected 403/500 samples for help_1
# Collected 404/500 samples for help_1
# Collected 405/500 samples for help_1
# Collected 406/500 samples for help_1
# Collected 407/500 samples for help_1
# Collected 408/500 samples for help_1
# Collected 409/500 samples for help_1
# Collected 410/500 samples for help_1
# Collected 411/500 samples for help_1
# Collected 412/500 samples for help_1
# Collected 413/500 samples for help_1
# Collected 414/500 samples for help_1
# Collected 415/500 samples for help_1
# Collected 416/500 samples for help_1
# Collected 417/500 samples for help_1
# Collected 418/500 samples for help_1
# Collected 419/500 samples for help_1
# Collected 420/500 samples for help_1
# Collected 421/500 samples for help_1
# Collected 422/500 samples for help_1
# Collected 423/500 samples for help_1
# Collected 424/500 samples for help_1
# Collected 425/500 samples for help_1
# Collected 426/500 samples for help_1
# Collected 427/500 samples for help_1
# Collected 428/500 samples for help_1
# Collected 429/500 samples for help_1
# Collected 430/500 samples for help_1
# Collected 431/500 samples for help_1
# Collected 432/500 samples for help_1
# Collected 433/500 samples for help_1
# Collected 434/500 samples for help_1
# Collected 435/500 samples for help_1
# Collected 436/500 samples for help_1
# Collected 437/500 samples for help_1
# Collected 438/500 samples for help_1
# Collected 439/500 samples for help_1
# Collected 440/500 samples for help_1
# Collected 441/500 samples for help_1
# Collected 442/500 samples for help_1
# Collected 443/500 samples for help_1
# Collected 444/500 samples for help_1
# Collected 445/500 samples for help_1
# Collected 446/500 samples for help_1
# Collected 447/500 samples for help_1
# Collected 448/500 samples for help_1
# Collected 449/500 samples for help_1
# Collected 450/500 samples for help_1
# Collected 451/500 samples for help_1
# Collected 452/500 samples for help_1
# Collected 453/500 samples for help_1
# Collected 454/500 samples for help_1
# Collected 455/500 samples for help_1
# Collected 456/500 samples for help_1
# Collected 457/500 samples for help_1
# Collected 458/500 samples for help_1
# Collected 459/500 samples for help_1
# Collected 460/500 samples for help_1
# Collected 461/500 samples for help_1
# Collected 462/500 samples for help_1
# Collected 463/500 samples for help_1
# Collected 464/500 samples for help_1
# Collected 465/500 samples for help_1
# Collected 466/500 samples for help_1
# Collected 467/500 samples for help_1
# Collected 468/500 samples for help_1
# Collected 469/500 samples for help_1
# Collected 470/500 samples for help_1
# Collected 471/500 samples for help_1
# Collected 472/500 samples for help_1
# Collected 473/500 samples for help_1
# Collected 474/500 samples for help_1
# Collected 475/500 samples for help_1
# Collected 476/500 samples for help_1
# Collected 477/500 samples for help_1
# Collected 478/500 samples for help_1
# Collected 479/500 samples for help_1
# Collected 480/500 samples for help_1
# Collected 481/500 samples for help_1
# Collected 482/500 samples for help_1
# Collected 483/500 samples for help_1
# Collected 484/500 samples for help_1
# Collected 485/500 samples for help_1
# Collected 486/500 samples for help_1
# Collected 487/500 samples for help_1
# Collected 488/500 samples for help_1
# Collected 489/500 samples for help_1
# Collected 490/500 samples for help_1
# Collected 491/500 samples for help_1
# Collected 492/500 samples for help_1
# Collected 493/500 samples for help_1
# Collected 494/500 samples for help_1
# Collected 495/500 samples for help_1
# Collected 496/500 samples for help_1
# Collected 497/500 samples for help_1
# Collected 498/500 samples for help_1
# Collected 499/500 samples for help_1
# Collected 500/500 samples for help_1
# Collected 1/500 samples for help_2
# Collected 2/500 samples for help_2
# Collected 3/500 samples for help_2
# Collected 4/500 samples for help_2
# Collected 5/500 samples for help_2
# Collected 6/500 samples for help_2
# Collected 7/500 samples for help_2
# Collected 8/500 samples for help_2
# Collected 9/500 samples for help_2
# Collected 10/500 samples for help_2
# Collected 11/500 samples for help_2
# Collected 12/500 samples for help_2
# Collected 13/500 samples for help_2
# Collected 14/500 samples for help_2
# Collected 15/500 samples for help_2
# Collected 16/500 samples for help_2
# Collected 17/500 samples for help_2
# Collected 18/500 samples for help_2
# Collected 19/500 samples for help_2
# Collected 20/500 samples for help_2
# Collected 21/500 samples for help_2
# Collected 22/500 samples for help_2
# Collected 23/500 samples for help_2
# Collected 24/500 samples for help_2
# Collected 25/500 samples for help_2
# Collected 26/500 samples for help_2
# Collected 27/500 samples for help_2
# Collected 28/500 samples for help_2
# Collected 29/500 samples for help_2
# Collected 30/500 samples for help_2
# Collected 31/500 samples for help_2
# Collected 32/500 samples for help_2
# Collected 33/500 samples for help_2
# Collected 34/500 samples for help_2
# Collected 35/500 samples for help_2
# Collected 36/500 samples for help_2
# Collected 37/500 samples for help_2
# Collected 38/500 samples for help_2
# Collected 39/500 samples for help_2
# Collected 40/500 samples for help_2
# Collected 41/500 samples for help_2
# Collected 42/500 samples for help_2
# Collected 43/500 samples for help_2
# Collected 44/500 samples for help_2
# Collected 45/500 samples for help_2
# Collected 46/500 samples for help_2
# Collected 47/500 samples for help_2
# Collected 48/500 samples for help_2
# Collected 49/500 samples for help_2
# Collected 50/500 samples for help_2
# Collected 51/500 samples for help_2
# Collected 52/500 samples for help_2
# Collected 53/500 samples for help_2
# Collected 54/500 samples for help_2
# Collected 55/500 samples for help_2
# Collected 56/500 samples for help_2
# Collected 57/500 samples for help_2
# Collected 58/500 samples for help_2
# Collected 59/500 samples for help_2
# Collected 60/500 samples for help_2
# Collected 61/500 samples for help_2
# Collected 62/500 samples for help_2
# Collected 63/500 samples for help_2
# Collected 64/500 samples for help_2
# Collected 65/500 samples for help_2
# Collected 66/500 samples for help_2
# Collected 67/500 samples for help_2
# Collected 68/500 samples for help_2
# Collected 69/500 samples for help_2
# Collected 70/500 samples for help_2
# Collected 71/500 samples for help_2
# Collected 72/500 samples for help_2
# Collected 73/500 samples for help_2
# Collected 74/500 samples for help_2
# Collected 75/500 samples for help_2
# Collected 76/500 samples for help_2
# Collected 77/500 samples for help_2
# Collected 78/500 samples for help_2
# Collected 79/500 samples for help_2
# Collected 80/500 samples for help_2
# Collected 81/500 samples for help_2
# Collected 82/500 samples for help_2
# Collected 83/500 samples for help_2
# Collected 84/500 samples for help_2
# Collected 85/500 samples for help_2
# Collected 86/500 samples for help_2
# Collected 87/500 samples for help_2
# Collected 88/500 samples for help_2
# Collected 89/500 samples for help_2
# Collected 90/500 samples for help_2
# Collected 91/500 samples for help_2
# Collected 92/500 samples for help_2
# Collected 93/500 samples for help_2
# Collected 94/500 samples for help_2
# Collected 95/500 samples for help_2
# Collected 96/500 samples for help_2
# Collected 97/500 samples for help_2
# Collected 98/500 samples for help_2
# Collected 99/500 samples for help_2
# Collected 100/500 samples for help_2
# Collected 101/500 samples for help_2
# Collected 102/500 samples for help_2
# Collected 103/500 samples for help_2
# Collected 104/500 samples for help_2
# Collected 105/500 samples for help_2
# Collected 106/500 samples for help_2
# Collected 107/500 samples for help_2
# Collected 108/500 samples for help_2
# Collected 109/500 samples for help_2
# Collected 110/500 samples for help_2
# Collected 111/500 samples for help_2
# Collected 112/500 samples for help_2
# Collected 113/500 samples for help_2
# Collected 114/500 samples for help_2
# Collected 115/500 samples for help_2
# Collected 116/500 samples for help_2
# Collected 117/500 samples for help_2
# Collected 118/500 samples for help_2
# Collected 119/500 samples for help_2
# Collected 120/500 samples for help_2
# Collected 121/500 samples for help_2
# Collected 122/500 samples for help_2
# Collected 123/500 samples for help_2
# Collected 124/500 samples for help_2
# Collected 125/500 samples for help_2
# Collected 126/500 samples for help_2
# Collected 127/500 samples for help_2
# Collected 128/500 samples for help_2
# Collected 129/500 samples for help_2
# Collected 130/500 samples for help_2
# Collected 131/500 samples for help_2
# Collected 132/500 samples for help_2
# Collected 133/500 samples for help_2
# Collected 134/500 samples for help_2
# Collected 135/500 samples for help_2
# Collected 136/500 samples for help_2
# Collected 137/500 samples for help_2
# Collected 138/500 samples for help_2
# Collected 139/500 samples for help_2
# Collected 140/500 samples for help_2
# Collected 141/500 samples for help_2
# Collected 142/500 samples for help_2
# Collected 143/500 samples for help_2
# Collected 144/500 samples for help_2
# Collected 145/500 samples for help_2
# Collected 146/500 samples for help_2
# Collected 147/500 samples for help_2
# Collected 148/500 samples for help_2
# Collected 149/500 samples for help_2
# Collected 150/500 samples for help_2
# Collected 151/500 samples for help_2
# Collected 152/500 samples for help_2
# Collected 153/500 samples for help_2
# Collected 154/500 samples for help_2
# Collected 155/500 samples for help_2
# Collected 156/500 samples for help_2
# Collected 157/500 samples for help_2
# Collected 158/500 samples for help_2
# Collected 159/500 samples for help_2
# Collected 160/500 samples for help_2
# Collected 161/500 samples for help_2
# Collected 162/500 samples for help_2
# Collected 163/500 samples for help_2
# Collected 164/500 samples for help_2
# Collected 165/500 samples for help_2
# Collected 166/500 samples for help_2
# Collected 167/500 samples for help_2
# Collected 168/500 samples for help_2
# Collected 169/500 samples for help_2
# Collected 170/500 samples for help_2
# Collected 171/500 samples for help_2
# Collected 172/500 samples for help_2
# Collected 173/500 samples for help_2
# Collected 174/500 samples for help_2
# Collected 175/500 samples for help_2
# Collected 176/500 samples for help_2
# Collected 177/500 samples for help_2
# Collected 178/500 samples for help_2
# Collected 179/500 samples for help_2
# Collected 180/500 samples for help_2
# Collected 181/500 samples for help_2
# Collected 182/500 samples for help_2
# Collected 183/500 samples for help_2
# Collected 184/500 samples for help_2
# Collected 185/500 samples for help_2
# Collected 186/500 samples for help_2
# Collected 187/500 samples for help_2
# Collected 188/500 samples for help_2
# Collected 189/500 samples for help_2
# Collected 190/500 samples for help_2
# Collected 191/500 samples for help_2
# Collected 192/500 samples for help_2
# Collected 193/500 samples for help_2
# Collected 194/500 samples for help_2
# Collected 195/500 samples for help_2
# Collected 196/500 samples for help_2
# Collected 197/500 samples for help_2
# Collected 198/500 samples for help_2
# Collected 199/500 samples for help_2
# Collected 200/500 samples for help_2
# Collected 201/500 samples for help_2
# Collected 202/500 samples for help_2
# Collected 203/500 samples for help_2
# Collected 204/500 samples for help_2
# Collected 205/500 samples for help_2
# Collected 206/500 samples for help_2
# Collected 207/500 samples for help_2
# Collected 208/500 samples for help_2
# Collected 209/500 samples for help_2
# Collected 210/500 samples for help_2
# Collected 211/500 samples for help_2
# Collected 212/500 samples for help_2
# Collected 213/500 samples for help_2
# Collected 214/500 samples for help_2
# Collected 215/500 samples for help_2
# Collected 216/500 samples for help_2
# Collected 217/500 samples for help_2
# Collected 218/500 samples for help_2
# Collected 219/500 samples for help_2
# Collected 220/500 samples for help_2
# Collected 221/500 samples for help_2
# Collected 222/500 samples for help_2
# Collected 223/500 samples for help_2
# Collected 224/500 samples for help_2
# Collected 225/500 samples for help_2
# Collected 226/500 samples for help_2
# Collected 227/500 samples for help_2
# Collected 228/500 samples for help_2
# Collected 229/500 samples for help_2
# Collected 230/500 samples for help_2
# Collected 231/500 samples for help_2
# Collected 232/500 samples for help_2
# Collected 233/500 samples for help_2
# Collected 234/500 samples for help_2
# Collected 235/500 samples for help_2
# Collected 236/500 samples for help_2
# Collected 237/500 samples for help_2
# Collected 238/500 samples for help_2
# Collected 239/500 samples for help_2
# Collected 240/500 samples for help_2
# Collected 241/500 samples for help_2
# Collected 242/500 samples for help_2
# Collected 243/500 samples for help_2
# Collected 244/500 samples for help_2
# Collected 245/500 samples for help_2
# Collected 246/500 samples for help_2
# Collected 247/500 samples for help_2
# Collected 248/500 samples for help_2
# Collected 249/500 samples for help_2
# Collected 250/500 samples for help_2
# Collected 251/500 samples for help_2
# Collected 252/500 samples for help_2
# Collected 253/500 samples for help_2
# Collected 254/500 samples for help_2
# Collected 255/500 samples for help_2
# Collected 256/500 samples for help_2
# Collected 257/500 samples for help_2
# Collected 258/500 samples for help_2
# Collected 259/500 samples for help_2
# Collected 260/500 samples for help_2
# Collected 261/500 samples for help_2
# Collected 262/500 samples for help_2
# Collected 263/500 samples for help_2
# Collected 264/500 samples for help_2
# Collected 265/500 samples for help_2
# Collected 266/500 samples for help_2
# Collected 267/500 samples for help_2
# Collected 268/500 samples for help_2
# Collected 269/500 samples for help_2
# Collected 270/500 samples for help_2
# Collected 271/500 samples for help_2
# Collected 272/500 samples for help_2
# Collected 273/500 samples for help_2
# Collected 274/500 samples for help_2
# Collected 275/500 samples for help_2
# Collected 276/500 samples for help_2
# Collected 277/500 samples for help_2
# Collected 278/500 samples for help_2
# Collected 279/500 samples for help_2
# Collected 280/500 samples for help_2
# Collected 281/500 samples for help_2
# Collected 282/500 samples for help_2
# Collected 283/500 samples for help_2
# Collected 284/500 samples for help_2
# Collected 285/500 samples for help_2
# Collected 286/500 samples for help_2
# Collected 287/500 samples for help_2
# Collected 288/500 samples for help_2
# Collected 289/500 samples for help_2
# Collected 290/500 samples for help_2
# Collected 291/500 samples for help_2
# Collected 292/500 samples for help_2
# Collected 293/500 samples for help_2
# Collected 294/500 samples for help_2
# Collected 295/500 samples for help_2
# Collected 296/500 samples for help_2
# Collected 297/500 samples for help_2
# Collected 298/500 samples for help_2
# Collected 299/500 samples for help_2
# Collected 300/500 samples for help_2
# Collected 301/500 samples for help_2
# Collected 302/500 samples for help_2
# Collected 303/500 samples for help_2
# Collected 304/500 samples for help_2
# Collected 305/500 samples for help_2
# Collected 306/500 samples for help_2
# Collected 307/500 samples for help_2
# Collected 308/500 samples for help_2
# Collected 309/500 samples for help_2
# Collected 310/500 samples for help_2
# Collected 311/500 samples for help_2
# Collected 312/500 samples for help_2
# Collected 313/500 samples for help_2
# Collected 314/500 samples for help_2
# Collected 315/500 samples for help_2
# Collected 316/500 samples for help_2
# Collected 317/500 samples for help_2
# Collected 318/500 samples for help_2
# Collected 319/500 samples for help_2
# Collected 320/500 samples for help_2
# Collected 321/500 samples for help_2
# Collected 322/500 samples for help_2
# Collected 323/500 samples for help_2
# Collected 324/500 samples for help_2
# Collected 325/500 samples for help_2
# Collected 326/500 samples for help_2
# Collected 327/500 samples for help_2
# Collected 328/500 samples for help_2
# Collected 329/500 samples for help_2
# Collected 330/500 samples for help_2
# Collected 331/500 samples for help_2
# Collected 332/500 samples for help_2
# Collected 333/500 samples for help_2
# Collected 334/500 samples for help_2
# Collected 335/500 samples for help_2
# Collected 336/500 samples for help_2
# Collected 337/500 samples for help_2
# Collected 338/500 samples for help_2
# Collected 339/500 samples for help_2
# Collected 340/500 samples for help_2
# Collected 341/500 samples for help_2
# Collected 342/500 samples for help_2
# Collected 343/500 samples for help_2
# Collected 344/500 samples for help_2
# Collected 345/500 samples for help_2
# Collected 346/500 samples for help_2
# Collected 347/500 samples for help_2
# Collected 348/500 samples for help_2
# Collected 349/500 samples for help_2
# Collected 350/500 samples for help_2
# Collected 351/500 samples for help_2
# Collected 352/500 samples for help_2
# Collected 353/500 samples for help_2
# Collected 354/500 samples for help_2
# Collected 355/500 samples for help_2
# Collected 356/500 samples for help_2
# Collected 357/500 samples for help_2
# Collected 358/500 samples for help_2
# Collected 359/500 samples for help_2
# Collected 360/500 samples for help_2
# Collected 361/500 samples for help_2
# Collected 362/500 samples for help_2
# Collected 363/500 samples for help_2
# Collected 364/500 samples for help_2
# Collected 365/500 samples for help_2
# Collected 366/500 samples for help_2
# Collected 367/500 samples for help_2
# Collected 368/500 samples for help_2
# Collected 369/500 samples for help_2
# Collected 370/500 samples for help_2
# Collected 371/500 samples for help_2
# Collected 372/500 samples for help_2
# Collected 373/500 samples for help_2
# Collected 374/500 samples for help_2
# Collected 375/500 samples for help_2
# Collected 376/500 samples for help_2
# Collected 377/500 samples for help_2
# Collected 378/500 samples for help_2
# Collected 379/500 samples for help_2
# Collected 380/500 samples for help_2
# Collected 381/500 samples for help_2
# Collected 382/500 samples for help_2
# Collected 383/500 samples for help_2
# Collected 384/500 samples for help_2
# Collected 385/500 samples for help_2
# Collected 386/500 samples for help_2
# Collected 387/500 samples for help_2
# Collected 388/500 samples for help_2
# Collected 389/500 samples for help_2
# Collected 390/500 samples for help_2
# Collected 391/500 samples for help_2
# Collected 392/500 samples for help_2
# Collected 393/500 samples for help_2
# Collected 394/500 samples for help_2
# Collected 395/500 samples for help_2
# Collected 396/500 samples for help_2
# Collected 397/500 samples for help_2
# Collected 398/500 samples for help_2
# Collected 399/500 samples for help_2
# Collected 400/500 samples for help_2
# Collected 401/500 samples for help_2
# Collected 402/500 samples for help_2
# Collected 403/500 samples for help_2
# Collected 404/500 samples for help_2
# Collected 405/500 samples for help_2
# Collected 406/500 samples for help_2
# Collected 407/500 samples for help_2
# Collected 408/500 samples for help_2
# Collected 409/500 samples for help_2
# Collected 410/500 samples for help_2
# Collected 411/500 samples for help_2
# Collected 412/500 samples for help_2
# Collected 413/500 samples for help_2
# Collected 414/500 samples for help_2
# Collected 415/500 samples for help_2
# Collected 416/500 samples for help_2
# Collected 417/500 samples for help_2
# Collected 418/500 samples for help_2
# Collected 419/500 samples for help_2
# Collected 420/500 samples for help_2
# Collected 421/500 samples for help_2
# Collected 422/500 samples for help_2
# Collected 423/500 samples for help_2
# Collected 424/500 samples for help_2
# Collected 425/500 samples for help_2
# Collected 426/500 samples for help_2
# Collected 427/500 samples for help_2
# Collected 428/500 samples for help_2
# Collected 429/500 samples for help_2
# Collected 430/500 samples for help_2
# Collected 431/500 samples for help_2
# Collected 432/500 samples for help_2
# Collected 433/500 samples for help_2
# Collected 434/500 samples for help_2
# Collected 435/500 samples for help_2
# Collected 436/500 samples for help_2
# Collected 437/500 samples for help_2
# Collected 438/500 samples for help_2
# Collected 439/500 samples for help_2
# Collected 440/500 samples for help_2
# Collected 441/500 samples for help_2
# Collected 442/500 samples for help_2
# Collected 443/500 samples for help_2
# Collected 444/500 samples for help_2
# Collected 445/500 samples for help_2
# Collected 446/500 samples for help_2
# Collected 447/500 samples for help_2
# Collected 448/500 samples for help_2
# Collected 449/500 samples for help_2
# Collected 450/500 samples for help_2
# Collected 451/500 samples for help_2
# Collected 452/500 samples for help_2
# Collected 453/500 samples for help_2
# Collected 454/500 samples for help_2
# Collected 455/500 samples for help_2
# Collected 456/500 samples for help_2
# Collected 457/500 samples for help_2
# Collected 458/500 samples for help_2
# Collected 459/500 samples for help_2
# Collected 460/500 samples for help_2
# Collected 461/500 samples for help_2
# Collected 462/500 samples for help_2
# Collected 463/500 samples for help_2
# Collected 464/500 samples for help_2
# Collected 465/500 samples for help_2
# Collected 466/500 samples for help_2
# Collected 467/500 samples for help_2
# Collected 468/500 samples for help_2
# Collected 469/500 samples for help_2
# Collected 470/500 samples for help_2
# Collected 471/500 samples for help_2
# Collected 472/500 samples for help_2
# Collected 473/500 samples for help_2
# Collected 474/500 samples for help_2
# Collected 475/500 samples for help_2
# Collected 476/500 samples for help_2
# Collected 477/500 samples for help_2
# Collected 478/500 samples for help_2
# Collected 479/500 samples for help_2
# Collected 480/500 samples for help_2
# Collected 481/500 samples for help_2
# Collected 482/500 samples for help_2
# Collected 483/500 samples for help_2
# Collected 484/500 samples for help_2
# Collected 485/500 samples for help_2
# Collected 486/500 samples for help_2
# Collected 487/500 samples for help_2
# Collected 488/500 samples for help_2
# Collected 489/500 samples for help_2
# Collected 490/500 samples for help_2
# Collected 491/500 samples for help_2
# Collected 492/500 samples for help_2
# Collected 493/500 samples for help_2
# Collected 494/500 samples for help_2
# Collected 495/500 samples for help_2
# Collected 496/500 samples for help_2
# Collected 497/500 samples for help_2
# Collected 498/500 samples for help_2
# Collected 499/500 samples for help_2
# Collected 500/500 samples for help_2
